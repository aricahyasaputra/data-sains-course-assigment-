# %% [markdown]
# <a href="https://colab.research.google.com/github/aricahyasaputra/data-sains-course-assigment-/blob/main/%20Week%207%20/Tugas_7_Data_Sains.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Cleaning

# %%
# import library

import pandas as pd
import numpy as np

# %%
# load data

df = pd.read_csv("https://raw.githubusercontent.com/aricahyasaputra/data-sains-course-assigment-/main/Week%206/euw_challanger.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  kills  deaths  assists  killParticipation  \
# 0           0             0   11.0     5.0      7.0           3.600000
# 1           1             1   21.0    11.0     13.0           3.090909
# 2           2             2    9.0     7.0      8.0           2.428571
# 3           3             3   11.0     2.0      2.0           6.500000
# 4           4             4    9.0     3.0      4.0           4.333333
#
#         kda  goldPerMinute  totalMinionsKilled     gold  totalDamageDealt  \
# 0  3.600000     509.580253               243.0  14950.0          225213.0
# 1  3.090909     461.392738               264.0  20375.0          341115.0
# 2  2.428571     394.271504               140.0   9325.0           95379.0
# 3  6.500000     513.628158               187.0  12275.0          147991.0
# 4  4.333333     559.206714               337.0  17950.0          355498.0
#
#    visionScore  visionScorePerMinute  skillshotsDodged  skillshotsHit    win
# ...

# %%
# periksa tipe datanya utk masing2 varibael/kolom/fitur dengan .dtypes

print(df.dtypes)
# Out:
# Unnamed: 0                int64
# Unnamed: 0.1              int64
# kills                   float64
# deaths                  float64
# assists                 float64
# killParticipation       float64
# kda                     float64
# goldPerMinute           float64
# totalMinionsKilled      float64
# gold                    float64
# totalDamageDealt        float64
# visionScore             float64
# visionScorePerMinute    float64
# skillshotsDodged        float64
# skillshotsHit           float64
# win                        bool
# dtype: object

# %%
# melihat statistik dasar 

df.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1       kills       deaths      assists  \
# count  5624.000000   5624.000000  5624.00000  5624.000000  5624.000000
# mean   2834.936700   2834.936700     6.11362     5.315434     8.372155
# std    1647.448052   1647.448052     4.98096     3.280757     6.386453
# min       0.000000      0.000000     0.00000     0.000000     0.000000
# 25%    1405.750000   1405.750000     2.00000     3.000000     4.000000
# 50%    2822.500000   2822.500000     5.00000     5.000000     7.000000
# 75%    4266.250000   4266.250000     9.00000     7.000000    11.000000
# max    5701.000000   5701.000000    44.00000    22.000000    48.000000
#
#        killParticipation          kda  goldPerMinute  totalMinionsKilled  \
# count        5624.000000  5624.000000    5624.000000         5624.000000
# mean            4.012126     4.012126     437.587685          117.033073
# std             4.243153     4.243153     135.162035           84.008546
# ...

# %% [markdown]
# #Membuang (drop) Kolom

# %%
# melihat pada lima entri pertama 

df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  kills  deaths  assists  killParticipation  \
# 0           0             0   11.0     5.0      7.0           3.600000
# 1           1             1   21.0    11.0     13.0           3.090909
# 2           2             2    9.0     7.0      8.0           2.428571
# 3           3             3   11.0     2.0      2.0           6.500000
# 4           4             4    9.0     3.0      4.0           4.333333
#
#         kda  goldPerMinute  totalMinionsKilled     gold  totalDamageDealt  \
# 0  3.600000     509.580253               243.0  14950.0          225213.0
# 1  3.090909     461.392738               264.0  20375.0          341115.0
# 2  2.428571     394.271504               140.0   9325.0           95379.0
# 3  6.500000     513.628158               187.0  12275.0          147991.0
# 4  4.333333     559.206714               337.0  17950.0          355498.0
#
#    visionScore  visionScorePerMinute  skillshotsDodged  skillshotsHit    win
# ...

# %% [markdown]
# Ada beberapa kolom yang tidak dgunakan yaitu unnamed 0 dan unnamed 0.1.

# %%
# memilih kolom-kolom yang akan di drop 

to_drop = ['Unnamed: 0', 
           'Unnamed: 0.1']

# %%
# melakukan drop pada data yang dipilih

df.drop(to_drop, inplace=True, axis=1)

# %%
# inspeksi ulang DataFrame, kolom yang tidak diinginkan sudah dibuang

df.head()
# Out:
#    kills  deaths  assists  killParticipation       kda  goldPerMinute  \
# 0   11.0     5.0      7.0           3.600000  3.600000     509.580253
# 1   21.0    11.0     13.0           3.090909  3.090909     461.392738
# 2    9.0     7.0      8.0           2.428571  2.428571     394.271504
# 3   11.0     2.0      2.0           6.500000  6.500000     513.628158
# 4    9.0     3.0      4.0           4.333333  4.333333     559.206714
#
#    totalMinionsKilled     gold  totalDamageDealt  visionScore  \
# 0               243.0  14950.0          225213.0         51.0
# 1               264.0  20375.0          341115.0         76.0
# 2               140.0   9325.0           95379.0         38.0
# 3               187.0  12275.0          147991.0         28.0
# 4               337.0  17950.0          355498.0         74.0
#
#    visionScorePerMinute  skillshotsDodged  skillshotsHit    win
# 0              1.558169              31.0           25.0   True
# ...

# %% [markdown]
# Disini terlihat column yang didrop telah tidak ada sehingga terbukti berhasil

# %% [markdown]
# Kita coba reset datanta untuk mencoba alternatif membuang kolom

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aricahyasaputra/data-sains-course-assigment-/main/Week%206/euw_challanger.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  kills  deaths  assists  killParticipation  \
# 0           0             0   11.0     5.0      7.0           3.600000
# 1           1             1   21.0    11.0     13.0           3.090909
# 2           2             2    9.0     7.0      8.0           2.428571
# 3           3             3   11.0     2.0      2.0           6.500000
# 4           4             4    9.0     3.0      4.0           4.333333
#
#         kda  goldPerMinute  totalMinionsKilled     gold  totalDamageDealt  \
# 0  3.600000     509.580253               243.0  14950.0          225213.0
# 1  3.090909     461.392738               264.0  20375.0          341115.0
# 2  2.428571     394.271504               140.0   9325.0           95379.0
# 3  6.500000     513.628158               187.0  12275.0          147991.0
# 4  4.333333     559.206714               337.0  17950.0          355498.0
#
#    visionScore  visionScorePerMinute  skillshotsDodged  skillshotsHit    win
# ...

# %% [markdown]
# Alternatif untuk membuang kolom

# %%
df.drop(columns=to_drop, inplace=True)

# %%
# inspeksi ulang DataFrame, kolom yang tidak diinginkan sudah dibuang

df.head()
# Out:
#    kills  deaths  assists  killParticipation       kda  goldPerMinute  \
# 0   11.0     5.0      7.0           3.600000  3.600000     509.580253
# 1   21.0    11.0     13.0           3.090909  3.090909     461.392738
# 2    9.0     7.0      8.0           2.428571  2.428571     394.271504
# 3   11.0     2.0      2.0           6.500000  6.500000     513.628158
# 4    9.0     3.0      4.0           4.333333  4.333333     559.206714
#
#    totalMinionsKilled     gold  totalDamageDealt  visionScore  \
# 0               243.0  14950.0          225213.0         51.0
# 1               264.0  20375.0          341115.0         76.0
# 2               140.0   9325.0           95379.0         38.0
# 3               187.0  12275.0          147991.0         28.0
# 4               337.0  17950.0          355498.0         74.0
#
#    visionScorePerMinute  skillshotsDodged  skillshotsHit    win
# 0              1.558169              31.0           25.0   True
# ...

# %% [markdown]
# Disini terlihat column yang didrop telah tidak ada sehingga terbukti berhasil

# %% [markdown]
# #Mengubah Indeks di DataFrame

# %% [markdown]
# Untuk bagian ini saya menggunakan data set [vgsales](https://) karena menurut saya lebih cocok karena ada columns rank

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aricahyasaputra/data-sains-course-assigment-/main/Week%206/vgsales.csv")
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# cek nilai unik rank

df['Rank'].is_unique
# Out:
# True

# %%
# ganti indeks yang ada pada kolom menggunakan set_index

df = df.set_index('Rank')
df.head()
# Out:
#                           Name Platform    Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006.0        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %%
# akses record ke 206

df.loc[100]

# .loc[] --> seleksi dengan menggunakan label/bilangan bulat
# Out:
# Name              Battlefield 3
# Platform                   X360
# Year                     2011.0
# Genre                   Shooter
# Publisher       Electronic Arts
# NA_Sales                   4.46
# EU_Sales                   2.13
# JP_Sales                   0.06
# Other_Sales                0.69
# Global_Sales               7.34
# Name: 100, dtype: object

# %% [markdown]
# Secara default, metode mengembalikan salinan objek yang dimodifikasi dan tidak membuat perubahan secara langsung ke objek. Hal ini dapat dihindari dengan mengatur parameter inplace:

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aricahyasaputra/data-sains-course-assigment-/main/Week%206/vgsales.csv")
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.set_index('Rank', inplace=True)
df.head()
# Out:
#                           Name Platform    Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006.0        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# #Merapihkan Fields dalam Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aricahyasaputra/data-sains-course-assigment-/main/Week%206/vgsales.csv")
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# menghitung frekuensi nilai objek

df.dtypes.value_counts()
# Out:
# float64    6
# object     4
# int64      1
# dtype: int64

# %% [markdown]
# Satu kolom yang masuk akal untuk menerapkan nilai numerik adalah tanggal publikasi sehingga kita dapat melakukan perhitungan di awal:

# %%
# seleksi data dari Year dengan output hanya pada field tanggal publikasi

df.loc[1996:, 'Name'].head(10)
# Out:
# 1996                                      Mega Man X4
# 1997                         Naruto: Clash of Ninja 2
# 1998                 Dance Dance Revolution SuperNOVA
# 1999                                            Brink
# 2000                         F-Zero: Maximum Velocity
# 2001                                     Bomberman 64
# 2002                     Jeremy McGrath Supercross 98
# 2003    LEGO Indiana Jones 2: The Adventure Continues
# 2004                                     Project CARS
# 2005                      Need for Speed: Most Wanted
# Name: Name, dtype: object

# %% [markdown]
# Game tertentu hanya memiliki satu tanggal publikasi. Oleh karena itu perlu dilakukan hal berikut:

# %% [markdown]
# Kita ubah terlebih dahulu dari float ke str

# %%
df['Year'] = df['Year'].astype(str)
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#jalankan regex di dataset

extr = df['Year'].str.extract(r'^(\d{4})', expand=False)
extr.head()

# expand=False: --> Jika Benar, kembalikan  DataFrame dengan satu kolom per grup tangkapan.  
# Jika Salah, kembalikan Seri/Indeks jika ada satu  grup tangkapan atau DataFrame jika ada beberapa  grup tangkapan.
# Out:
# 0    2006
# 1    1985
# 2    2008
# 3    2009
# 4    1996
# Name: Year, dtype: object

# %%
# mendapatkan versi numeriknya dengan perintah pd.to_numeric

df['Year'] = pd.to_numeric(extr)
df['Year'].dtype
# Out:
# dtype('float64')

# %%
# perhitungan pada nilai valid yang tersisa

df['Year'].isnull().sum() / len(df)
# Out:
# 0.016327268345583804

# %% [markdown]
# Ini menghasilkan sekitar 1/100 nilai yang hilang, cost yang cukup kecil dampaknya untuk saat ini karena dapat melakukan perhitungan pada nilai valid yang tersisa:

# %% [markdown]
# #Membersihkan Kolom dengan Kombinasi metode str dengan NumPy

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aricahyasaputra/data-sains-course-assigment-/main/Week%206/vgsales.csv")
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# isi kolom 'Platform'

df['Platform'].head(10)
# Out:
# 0    Wii
# 1    NES
# 2    Wii
# 3    Wii
# 4     GB
# 5     GB
# 6     DS
# 7    Wii
# 8    Wii
# 9    NES
# Name: Platform, dtype: object

# %% [markdown]
# Kita tambahkan baris agar bisa sebagai contoh

# %%
df2 = {'Rank': '16601', 'Name': 'Aruchamy', 'Platform': 'DS', 'Year':'2010','Genre':'Role Playing', 'Publisher':'Nintendo', 'NA_Sales':'11', 'EU_Sales':'12','JP_Sales':'13','Other_Sales':'13', 'Global_Sales':'15'}

df = df.append(df2, ignore_index = True)
df.tail()
# Out:
#         Rank                                              Name Platform  \
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
# 16598  16601                                          Aruchamy       DS
#
#          Year         Genre   Publisher NA_Sales EU_Sales JP_Sales  \
# 16594  2003.0       Shooter  Infogrames     0.01      0.0      0.0
# 16595  2008.0        Racing  Activision      0.0      0.0      0.0
# 16596  2010.0        Puzzle    7G//AMES      0.0     0.01      0.0
# 16597  2003.0      Platform     Wanadoo     0.01      0.0      0.0
# 16598    2010  Role Playing    Nintendo       11       12       13
#
#       Other_Sales Global_Sales
# 16594         0.0         0.01
# 16595         0.0         0.01
# 16596         0.0         0.01
# ...

# %%
df.loc[16598]
# Out:
# Rank                   16601
# Name                Aruchamy
# Platform                  DS
# Year                    2010
# Genre           Role Playing
# Publisher           Nintendo
# NA_Sales                  11
# EU_Sales                  12
# JP_Sales                  13
# Other_Sales               13
# Global_Sales              15
# Name: 16598, dtype: object

# %%
df.loc[4]
# Out:
# Rank                                   5
# Name            Pokemon Red/Pokemon Blue
# Platform                              GB
# Year                              1996.0
# Genre                       Role-Playing
# Publisher                       Nintendo
# NA_Sales                           11.27
# EU_Sales                            8.89
# JP_Sales                           10.22
# Other_Sales                          1.0
# Global_Sales                       31.37
# Name: 4, dtype: object

# %% [markdown]
# Pada dua entri di atas, dua Genre (Role Playing) namun salah satunya memilik tanda hubung (-)

# %%
# mendapatkan boolean mask

pub = df['Genre']
rolePlaying = pub.str.contains('Role-Playing')
rolePlaying[:5]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Genre, dtype: bool

# %%
df['Genre'] = np.where(rolePlaying, 'Role Playing', pub.str.replace('-', ' '))
df['Genre'].head()
# Out:
# 0          Sports
# 1        Platform
# 2          Racing
# 3          Sports
# 4    Role Playing
# Name: Genre, dtype: object

# %% [markdown]
# #Membersihkan Seluruh Dataset dengan Fungsi applymap

# %% [markdown]
# Karena menggunakan algoritma yang ibu di saya tidak bisa saya mencari lagoritma di stack overflow

# %%
df = pd.read_csv('/content/SMSA.txt', sep="\t" , header = None)
df.columns = ["city", "state", "JanTemp", "JulyTemp", "RelHum", "Rain", "Mortality", "Education", "PopDensity", "pNonWhite", "pWC","pop", "pophouse", "income", "HCPot", "NOxPot","S02Pot","NOx"]
																	
print(df)
# Out:
#                        city     state  JanTemp  JulyTemp  RelHum  Rain  \
# 0                      city     state  JanTemp  JulyTemp  RelHum  Rain
# 1                     Akron        OH       27        71      59    36
# 2   Albany-Schenectady-Troy        NY       23        72      57    35
# 3       Allentown-Bethlehem     PA-NJ       29        74      54    44
# 4                   Atlanta        GA       45        79      56    47
# ..                      ...       ...      ...       ...     ...   ...
# 56                  Wichita        KS       32        81      54    28
# 57               Wilmington  DE-NJ-MD       33        76      56    65
# 58                Worcester        MA       24        70      56    65
# 59                     York        PA       33        76      54    62
# 60        Youngstown-Warren        OH       28        72      58    38
#
#     Mortality  Education  PopDensity  pNonWhite   pWC      pop  pophouse  \
# ...

# %%
df.drop([0])
# Out:
#                                    city     state JanTemp JulyTemp RelHum  \
# 1                                 Akron        OH      27       71     59
# 2               Albany-Schenectady-Troy        NY      23       72     57
# 3                   Allentown-Bethlehem     PA-NJ      29       74     54
# 4                               Atlanta        GA      45       79     56
# 5                             Baltimore        MD      35       77     55
# 6                            Birmingham        AL      45       80     54
# 7                                Boston        MA      30       74     56
# 8                    Bridgeport-Milford        CT      30       73     56
# 9                               Buffalo        NY      24       70     61
# 10                               Canton        OH      27       72     59
# 11                          Chattanooga     TN-GA      42       79     56
# 12                              Chicago        IL      26       76     58
# ...

# %%
contoh_data = {0 : ['mock','python','real','numpy'],
               1 : ['Dataset','pandas','python','clean']}

contoh_dataframe = pd.DataFrame(contoh_data)

contoh_dataframe.head()
